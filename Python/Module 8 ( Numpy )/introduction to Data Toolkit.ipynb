# %%
""" Data Toolkit: 
    we are going to learn some very useful library: 
    numpy
    pandas
    matplotlib
    seaborn
    plotty
    bokeh
"""

# CRISP-DM : cross industry standard process for data mining.
#  Data mining: Getting insides from the data is know as Data mining.

# %%
from IPython.display import Image, display

display(Image(r"C:\MY SPACE\Downloads\CRISP.png"))
